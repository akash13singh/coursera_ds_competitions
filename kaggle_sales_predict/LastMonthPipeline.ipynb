# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import make_pipeline

# %%
data_path = "/home/akash/projects/AML/ds_comptetions/kaggle_sales_predict/data/"
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
print onlyfiles
# Out:
# ['shops.csv', 'test.csv', 'submission.csv', 'sales_train.csv', 'item_categories.csv', 'sample_submission.csv', 'submission_1.167.csv', 'items.csv']

# %%
categories = pd.read_csv(data_path+"item_categories.csv")

# %%
categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
categories.shape
# Out:
# (84, 2)

# %%
items = pd.read_csv(data_path+"items.csv")
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
items.shape
# Out:
# (22170, 3)

# %%
shops = pd.read_csv(data_path+"shops.csv")

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
shops.shape
# Out:
# (60, 2)

# %%
train = pd.read_csv(data_path+"sales_train.csv")
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
train.shape
# Out:
# (2935849, 6)

# %%
test = pd.read_csv(data_path+"test.csv")

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
test.shape
# Out:
# (214200, 3)

# %%
sample_submit = pd.read_csv(data_path+"sample_submission.csv")
sample_submit.head()
# Out:
#    ID  item_cnt_month
# 0   0             0.5
# 1   1             0.5
# 2   2             0.5
# 3   3             0.5
# 4   4             0.5

# %% [markdown]
# ### Create dumb benchmarks

# %%
test_all_zeroes = test[["ID"]] # if we take only a single ssuare brackets we get a series not a DF
test_all_zeroes["item_cnt_month"] = 0
test_all_zeroes.to_csv("all_0.csv",index=False)
# Out:
# /home/akash/.local/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test_all_zeroes.head()
# Out:
#    ID  item_cnt_month
# 0   0               0
# 1   1               0
# 2   2               0
# 3   3               0
# 4   4               0

# %% [markdown]
# ### all_0 benchmark = 1.25

# %%
test_all_ones = test[["ID"]]
test_all_ones["item_cnt_month"] = 1
test_all_ones.to_csv("all_1.csv",index=False)
# Out:
# /home/akash/.local/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### all_1s becnhmark = 1.41214

# %% [markdown]
# * score_last_month = 1.167
# * all_0s = 1.25
# * all_1s = 1.41214

# %% [markdown]
# ### Define Transformers

# %%
from functools import wraps
def transformer_decorator(fun):
    @wraps(fun)
    def wrapped(df,**kwargs):
        print("\n\n Applying transformer: %s"%fun.__name__)   
        df = fun(df,**kwargs)
        print df.head()
        return df
    return wrapped

# %%
@transformer_decorator
def transform_date(df):
    df["date"] = pd.to_datetime(df["date"], format="%d.%m.%Y")
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day
    return df

date_transformer = FunctionTransformer(transform_date, validate=False)

# %%
@transformer_decorator
def calculate_daily_sales(df):
    df["daily_sale"] = df["item_price"] * df["item_cnt_day"]
    return df

daily_sale_transformer = FunctionTransformer(calculate_daily_sales, validate=False)

# %%
@transformer_decorator
def aggregate_monthly_sales(df):
    df = train.groupby(["shop_id", "item_id", "date_block_num"], as_index=False).item_cnt_day.sum().\
    rename(columns={"item_cnt_day":"item_cnt_month"})
    return df
monthly_aggregate_transformer = FunctionTransformer(aggregate_monthly_sales, validate=False)

# %%
@transformer_decorator
def clip_monthly_sales(df):
    total = len(df)
    count_20 = df.loc[(df["item_cnt_month"]>20)].shape[0]
    count_0 = df.loc[(df["item_cnt_month"]<0)].shape[0]
    percent_20 = count_20/float(total)
    percent_0 = count_0/float(total)
    print "%f percent is less than 0"%percent_0
    print "%f percent is greater than 20"%percent_20
    df["item_cnt_month"] = df["item_cnt_month"].clip(0,20)
    return df

clip_sales_transformer = FunctionTransformer(clip_monthly_sales, validate=False)

# %%
# @transformer_decorator
# def add_last_month_sales(df):
#     df_last = df.loc[train["date_block_num"]==33]
#     last_month_dict =

# %% [markdown]
# ### Build Processing Pipeline

# %%
preprocess_pipeline = make_pipeline(
                        date_transformer, 
                        daily_sale_transformer, 
                        monthly_aggregate_transformer,
                        )

# %%
train = preprocess_pipeline.transform(train)
# Out:
#  Applying transformer: transform_date
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-01-02               0       59    22154      999.00           1.0
# 1 2013-01-03               0       25     2552      899.00           1.0
# 2 2013-01-05               0       25     2552      899.00          -1.0
# 3 2013-01-06               0       25     2554     1709.05           1.0
# 4 2013-01-15               0       25     2555     1099.00           1.0
#
#    year  month  day
# 0  2013      1    2
# 1  2013      1    3
# 2  2013      1    5
# 3  2013      1    6
# 4  2013      1   15
#
#
#  Applying transformer: calculate_daily_sales
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-01-02               0       59    22154      999.00           1.0
# 1 2013-01-03               0       25     2552      899.00           1.0
# 2 2013-01-05               0       25     2552      899.00          -1.0
# 3 2013-01-06               0       25     2554     1709.05           1.0
# 4 2013-01-15               0       25     2555     1099.00           1.0
#
#    year  month  day  daily_sale
# 0  2013      1    2      999.00
# 1  2013      1    3      899.00
# 2  2013      1    5     -899.00
# 3  2013      1    6     1709.05
# 4  2013      1   15     1099.00
#
#
#  Applying transformer: aggregate_monthly_sales
#    shop_id  item_id  date_block_num  item_cnt_month
# 0        0       30               1            31.0
# 1        0       31               1            11.0
# 2        0       32               0             6.0
# 3        0       32               1            10.0
# 4        0       33               0             3.0

# %% [markdown]
# ### Make Last Month Transformer

# %%
from sklearn.base import BaseEstimator, RegressorMixin

class LastMonthSaleTransformer(BaseEstimator, RegressorMixin):
    
    def __init__(self):
        pass
    
    def fit(self, X, y=None):
        X_last = X.loc[train["date_block_num"]==33]
        last_month_dict = X_last.groupby(["shop_id", "item_id"])["item_cnt_month"].apply(list).to_dict()
        self.last_month_dict_ = last_month_dict
        return self
    
    def transform(self, X, y=None):
        last_month_dict = self.last_month_dict_
        
        def fill_last_month(key):
            if key in last_month_dict:
                return last_month_dict[key][0]
            else:
                return np.NaN
        
        X["last_month_sales"] = X.apply( lambda row: fill_last_month((row["shop_id"], row["item_id"])) , axis=1)
        X["last_month_sales"] = X["last_month_sales"].fillna(0)
        return X

# %%
last_month_transformer = LastMonthSaleTransformer()
last_month_transformer.fit(train)
train = last_month_transformer.transform(train)

# %%
train
# Out:
#          shop_id  item_id  date_block_num  item_cnt_month  last_month_sales
# 0              0       30               1            31.0               0.0
# 1              0       31               1            11.0               0.0
# 2              0       32               0             6.0               0.0
# 3              0       32               1            10.0               0.0
# 4              0       33               0             3.0               0.0
# 5              0       33               1             3.0               0.0
# 6              0       35               0             1.0               0.0
# 7              0       35               1            14.0               0.0
# 8              0       36               1             1.0               0.0
# 9              0       40               1             1.0               0.0
# 10             0       42               1             1.0               0.0
# 11             0       43               0             1.0               0.0
# 12             0       49               1             2.0               0.0
# 13             0       51               0             2.0               0.0
# 14             0       51               1             3.0               0.0
# 15             0       57               1             1.0               0.0
# 16             0       59               1             1.0               0.0
# 17             0       61               0             1.0               0.0
# 18             0       75               0             1.0               0.0
# 19             0       85               1             1.0               0.0
# 20             0       88               0             1.0               0.0
# 21             0       95               0             1.0               0.0
# 22             0       96               0             1.0               0.0
# 23             0       97               1             1.0               0.0
# 24             0       98               0            25.0               0.0
# 25             0       98               1             5.0               0.0
# 26             0      111               0             1.0               0.0
# 27             0      111               1             1.0               0.0
# 28             0      115               1             1.0               0.0
# 29             0      136               1             1.0               0.0
# ...          ...      ...             ...             ...               ...
# 1609094       59    22134               0             2.0               0.0
# 1609095       59    22134               1             1.0               0.0
# 1609096       59    22139              24             1.0               0.0
# 1609097       59    22139              32             1.0               0.0
# 1608064       59    21361              33             1.0               1.0
# 1608074       59    21364              33             1.0               1.0
# 1608084       59    21369              33             2.0               2.0
# 1608129       59    21377              33             1.0               1.0
# 1608159       59    21386              33             1.0               1.0
# 1608193       59    21404              33             1.0               1.0
# 1608233       59    21427              33             1.0               1.0
# 1608284       59    21449              33             2.0               2.0
# 1608518       59    21672              33             1.0               1.0
# 1608654       59    21811              33             1.0               1.0
# 1608655       59    21812              33             1.0               1.0
# 1608998       59    22087              33             6.0               6.0
# 1609030       59    22088              33             2.0               2.0
# 1609047       59    22091              33             1.0               1.0
# 1609073       59    22100              33             1.0               1.0
# 1609076       59    22102              33             1.0               1.0
#
# [31531 rows x 5 columns]

# %%
last_month_transformer.last_month_dict_[(2,486)]
# Out:
# [3.0]

# %%
test = last_month_transformer.transform(test)

# %%
test["item_cnt_month"] = test["last_month_sales"]
test["item_cnt_month"] = test["item_cnt_month"].clip(0,20)

# %%
test.head(50)
# Out:
#     ID  shop_id  item_id  last_month_sales  item_cnt_month
# 0    0        5     5037               0.0             0.0
# 1    1        5     5320               0.0             0.0
# 2    2        5     5233               1.0             1.0
# 3    3        5     5232               0.0             0.0
# 4    4        5     5268               0.0             0.0
# 5    5        5     5039               1.0             1.0
# 6    6        5     5041               2.0             2.0
# 7    7        5     5046               0.0             0.0
# 8    8        5     5319               0.0             0.0
# 9    9        5     5003               0.0             0.0
# 10  10        5     4806               3.0             3.0
# 11  11        5     4843               0.0             0.0
# 12  12        5     4607               0.0             0.0
# 13  13        5     4869               0.0             0.0
# 14  14        5     4870               2.0             2.0
# 15  15        5     4872               6.0             6.0
# 16  16        5     4874               0.0             0.0
# 17  17        5     4678               0.0             0.0
# 18  18        5     4892               2.0             2.0
# 19  19        5     4964               0.0             0.0
# 20  20        5     4717               1.0             1.0
# 21  21        5     5002               0.0             0.0
# 22  22        5     5823               1.0             1.0
# 23  23        5     5814               1.0             1.0
# 24  24        5     5900               3.0             3.0
# 25  25        5     5907               0.0             0.0
# 26  26        5     5908               0.0             0.0
# 27  27        5     5643               0.0             0.0
# 28  28        5     5657               2.0             2.0
# 29  29        5     5675               7.0             7.0
# 30  30        5     5666               0.0             0.0
# 31  31        5     5668               0.0             0.0
# 32  32        5     5669               0.0             0.0
# 33  33        5     5672               0.0             0.0
# 34  34        5     5653               0.0             0.0
# 35  35        5     5678               0.0             0.0
# 36  36        5     5674               0.0             0.0
# 37  37        5     5671               0.0             0.0
# 38  38        5     5845               0.0             0.0
# 39  39        5     5841               0.0             0.0
# 40  40        5     5840               1.0             1.0
# 41  41        5     5820               0.0             0.0
# 42  42        5     5821               4.0             4.0
# 43  43        5     5822               3.0             3.0
# 44  44        5     5824               0.0             0.0
# 45  45        5     5826               0.0             0.0
# 46  46        5     5827               0.0             0.0
# 47  47        5     5828               0.0             0.0
# 48  48        5     5829               0.0             0.0
# 49  49        5     5837               2.0             2.0

# %% [markdown]
# ### Create last month sale benchmark

# %%
test[["ID", "item_cnt_month"]].to_csv("last_month.csv", index=False)

# %% [markdown]
# ### Score =1.167
